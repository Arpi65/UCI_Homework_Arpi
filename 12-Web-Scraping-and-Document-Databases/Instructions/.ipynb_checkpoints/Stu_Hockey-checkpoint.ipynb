# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Inside look at Colorado Avalanche
# Hope for long playoff run with Saad joining core of MacKinnon, Landeskog, Rantanen
# 2020-11-23
# -----------------
# Ovechkin can break Gretzky's NHL goals record, Jagr says
# Capitals forward, 188 shy of mark, must 'stay healthy and keep working as hard'
# 2020-11-23
# -----------------
# DeBrusk signs two-year, $7.35 million contract with Bruins
# Forward was restricted free agent, scored 35 points for Boston last season
# 2020-11-23
# -----------------
# Julien heart healthy for Canadiens, wants to coach as long as possible
# 60-year-old left playoffs in August to have procedure
# 2020-11-23
# -----------------
# Lundqvist joins Capitals teammates for first time at informal skate
# Goalie signed one-year contract Oct. 9 after playing 15 seasons with Rangers
# 2020-11-23
# -----------------
# Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas
# Will be worn multiple times this season; available for purchase starting Dec. 1
# 2020-11-16
# -----------------
# Coyne Schofield hired as Blackhawks' first female development coach
# Two-time Olympic medalist also will work as youth hockey growth specialist
# 2020-11-23
# -----------------
# #NHLTopPlayers: Top 10 Goalies
# NHL Network reveals best of current crop
# 2020-11-22
# -----------------
# Three questions facing Colorado Avalanche
# Starting goalie, physicality of defensemen among concerns
# 2020-11-23
# -----------------
# Most improved fantasy teams for 2020-21
# Sabres, Canadiens, Senators have much better outlook after offseason moves
# 2020-11-23
# -----------------
# NHL Free Agent Tracker
# Complete list of signings by team, available players
# 2020-11-23
# -----------------
# Lowry's father will coach him as Jets assistant
# Former NHL forward 'had to have Adam's blessing' before being hired
# 2020-11-23
# -----------------
# Sasakamoose, indigenous NHL pioneer, hospitalized with COVID-19
# 86-year-old receives outpouring of support from Commissioner Bettman, players
# 2020-11-23
# -----------------
# Color of Hockey: Smith happy original Sharks logo making comeback
# Artist's iconic image featured on Reverse Retro jerseys this season
# 2020-11-23
# -----------------
# Wild will name captain before season, GM says
# Parise, Suter could be among candidates to replace Koivu, who signed with Blue Jackets
# 2020-11-23
# -----------------
# 2020-21 NHL Trade Tracker
# Official deals since Oct. 1, 2020
# 2020-10-12
# -----------------
# Top goalie in NHL in 3 seasons debated
# Shesterkin, Vasilevskiy, Hellebuyck, Hart among favorites of NHL.com writers
# 2020-11-21
# -----------------
# Colorado Avalanche key statistics
# Kadri key to power-play success; Grubauer among best goalies at even strength
# 2020-11-23
# -----------------
# Khudobin expected to be ready for training camp for Stars after surgery
# Goalie had nerve issue in arm; Bishop, Seguin recovering
# 2020-11-20
# -----------------
# Colorado Avalanche fantasy preview for 2020-21
# Makar among best defensemen; MacKinnon, Rantanen lead elite forward group
# 2020-11-23
# -----------------
# Geoffrion continues NHL family legacy as Panthers exec
# Morenz's great-grandson, Bernie's grandson was fourth member of lineage to play for Canadiens
# 2020-11-22
# -----------------
# Canada World Juniors coaches serving 14-day quarantine for COVID-19
# Dyck, LaBarbera isolated after contact with staff member at evaluation camp who tested positive
# 2020-11-22
# -----------------
# Top prospects for Colorado Avalanche
# Byram, Timmins, Kaut on cusp, could make NHL impact this season
# 2020-11-23
# -----------------
# Vasilevskiy hoisting Stanley Cup on new mask
# Lightning goalie receives gift from helmet designer
# 2020-11-22
# -----------------
# Thornton will spark Maple Leafs, GM of Switzerland team says: report
# 41-year-old center leads NHL active players in points, assists
# 2020-11-20
# -----------------
# Schinkel, member of expansion Penguins, dies at 87
# Played 12 seasons in NHL, coached Pittsburgh to two postseason appearances
# 2020-11-21
# -----------------
# Thomas making adjustments on, off ice as pro career starts in Germany
# Kings forward prospect using opportunity with Eisbaren Berlin to get ready for NHL
# 2020-11-20
# -----------------
# Lightning trainer, Star Wars fanatic enjoys Stanley Cup with Baby Yoda
# Mike Poirier wore Darth Vader helmet for this day at home with trophy
# 2020-11-20
# -----------------
# Nov. 23: Gretzky scores 600th goal
# Plus: Gilbert plays final game; Bruins become second NHL team with 2,500 victories
# 2020-11-23

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5fbc519b90aa569e493eacb4'), 'header': 'Inside look at Colorado Avalanche', 'subheader': 'Hope for long playoff run with Saad joining core of MacKinnon, Landeskog, Rantanen', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacb5'), 'header': "Ovechkin can break Gretzky's NHL goals record, Jagr says", 'subheader': "Capitals forward, 188 shy of mark, must 'stay healthy and keep working as hard'", 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacb6'), 'header': 'DeBrusk signs two-year, $7.35 million contract with Bruins', 'subheader': 'Forward was restricted free agent, scored 35 points for Boston last season', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacb7'), 'header': 'Julien heart healthy for Canadiens, wants to coach as long as possible', 'subheader': '60-year-old left playoffs in August to have procedure', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacb8'), 'header': 'Lundqvist joins Capitals teammates for first time at informal skate', 'subheader': 'Goalie signed one-year contract Oct. 9 after playing 15 seasons with Rangers', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacb9'), 'header': 'Reverse Retro alternate jerseys for all 31 teams unveiled by NHL, adidas', 'subheader': 'Will be worn multiple times this season; available for purchase starting Dec. 1', 'date': '2020-11-16'}
# {'_id': ObjectId('5fbc519b90aa569e493eacba'), 'header': "Coyne Schofield hired as Blackhawks' first female development coach", 'subheader': 'Two-time Olympic medalist also will work as youth hockey growth specialist', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacbb'), 'header': '#NHLTopPlayers: Top 10 Goalies', 'subheader': 'NHL Network reveals best of current crop', 'date': '2020-11-22'}
# {'_id': ObjectId('5fbc519b90aa569e493eacbc'), 'header': 'Three questions facing Colorado Avalanche', 'subheader': 'Starting goalie, physicality of defensemen among concerns', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacbd'), 'header': 'Most improved fantasy teams for 2020-21', 'subheader': 'Sabres, Canadiens, Senators have much better outlook after offseason moves', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacbe'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacbf'), 'header': "Lowry's father will coach him as Jets assistant", 'subheader': "Former NHL forward 'had to have Adam's blessing' before being hired", 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc0'), 'header': 'Sasakamoose, indigenous NHL pioneer, hospitalized with COVID-19', 'subheader': '86-year-old receives outpouring of support from Commissioner Bettman, players', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc1'), 'header': 'Color of Hockey: Smith happy original Sharks logo making comeback', 'subheader': "Artist's iconic image featured on Reverse Retro jerseys this season", 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc2'), 'header': 'Wild will name captain before season, GM says', 'subheader': 'Parise, Suter could be among candidates to replace Koivu, who signed with Blue Jackets', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc3'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-10-12'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc4'), 'header': 'Top goalie in NHL in 3 seasons debated', 'subheader': 'Shesterkin, Vasilevskiy, Hellebuyck, Hart among favorites of NHL.com writers', 'date': '2020-11-21'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc5'), 'header': 'Colorado Avalanche key statistics', 'subheader': 'Kadri key to power-play success; Grubauer among best goalies at even strength', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc6'), 'header': 'Khudobin expected to be ready for training camp for Stars after surgery', 'subheader': 'Goalie had nerve issue in arm; Bishop, Seguin recovering', 'date': '2020-11-20'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc7'), 'header': 'Colorado Avalanche fantasy preview for 2020-21', 'subheader': 'Makar among best defensemen; MacKinnon, Rantanen lead elite forward group', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc8'), 'header': 'Geoffrion continues NHL family legacy as Panthers exec', 'subheader': "Morenz's great-grandson, Bernie's grandson was fourth member of lineage to play for Canadiens", 'date': '2020-11-22'}
# {'_id': ObjectId('5fbc519b90aa569e493eacc9'), 'header': 'Canada World Juniors coaches serving 14-day quarantine for COVID-19', 'subheader': 'Dyck, LaBarbera isolated after contact with staff member at evaluation camp who tested positive', 'date': '2020-11-22'}
# {'_id': ObjectId('5fbc519b90aa569e493eacca'), 'header': 'Top prospects for Colorado Avalanche', 'subheader': 'Byram, Timmins, Kaut on cusp, could make NHL impact this season', 'date': '2020-11-23'}
# {'_id': ObjectId('5fbc519b90aa569e493eaccb'), 'header': 'Vasilevskiy hoisting Stanley Cup on new mask', 'subheader': 'Lightning goalie receives gift from helmet designer', 'date': '2020-11-22'}
# {'_id': ObjectId('5fbc519b90aa569e493eaccc'), 'header': 'Thornton will spark Maple Leafs, GM of Switzerland team says: report', 'subheader': '41-year-old center leads NHL active players in points, assists', 'date': '2020-11-20'}
# {'_id': ObjectId('5fbc519b90aa569e493eaccd'), 'header': 'Schinkel, member of expansion Penguins, dies at 87', 'subheader': 'Played 12 seasons in NHL, coached Pittsburgh to two postseason appearances', 'date': '2020-11-21'}
# {'_id': ObjectId('5fbc519b90aa569e493eacce'), 'header': 'Thomas making adjustments on, off ice as pro career starts in Germany', 'subheader': 'Kings forward prospect using opportunity with Eisbaren Berlin to get ready for NHL', 'date': '2020-11-20'}
# {'_id': ObjectId('5fbc519b90aa569e493eaccf'), 'header': 'Lightning trainer, Star Wars fanatic enjoys Stanley Cup with Baby Yoda', 'subheader': 'Mike Poirier wore Darth Vader helmet for this day at home with trophy', 'date': '2020-11-20'}
# {'_id': ObjectId('5fbc519b90aa569e493eacd0'), 'header': 'Nov. 23: Gretzky scores 600th goal', 'subheader': 'Plus: Gilbert plays final game; Bruins become second NHL team with 2,500 victories', 'date': '2020-11-23'}
