# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Google API Key
from config import gkey

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = "Seattle, Washington"

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of Seattle, WA")

# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# Convert to JSON
seattle_geo = response.json()

# Extract lat/lng
lat = seattle_geo["results"][0]["geometry"]["location"]["lat"]
lng = seattle_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of Seattle, WA
# Seattle, Washington: 47.6062095, -122.3320708

# %%
# 2. What are the geocoordinates (latitude and longitude) of The White House?
# update params dict
target_city = "The White House"
params["address"] = target_city


print("Drill #2: The Geocoordinates of the White House")


# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

dc_geo = response.json()
# Extract lat/lng
lat = dc_geo["results"][0]["geometry"]["location"]["lat"]
lng = dc_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #2: The Geocoordinates of the White House
# The White House: 38.8976763, -77.0365298

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type = "bicycle_store"
seattle_coords = "47.6062095,-122.3320708"
radius = 8000

# rewrite params dict

params = {
    "location": seattle_coords,
    "types": target_type,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #3: A Bike Store in Seattle, WA")

# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

seattle_bikes = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(seattle_bikes, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
print(seattle_bikes["results"][0]["name"])
print(seattle_bikes["results"][0]["vicinity"])
# Out:
# Drill #3: A Bike Store in Seattle, WA
# REI
# 222 Yale Avenue North, Seattle

# %%
print(json.dumps(seattle_bikes, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CtQETQIAAKhn8XaUgHn9ssgybpWtupsjYexez5Fa8TRqFCUxXMtKw2IOP1NNI95nOY6kqFaBRGkr92FswR0DTXuS4jKKyQNhewguSdOLvySqeb2PKGt244TDF_x2eHJc9_1CuP7q1n9XHvtpg6yp0dvVoe2QZFP5XUoQDSEpeeDrWR2aMqsw78tYqKm9Hcw_B3eefnumWdBhzB5Zg6bVz1J_CRnl1ib6cixS0AZs6AiQ8ckqTdu5P9vFTdBK9sM7XYHRhB7GCqNZgoGCB4wCUke283nkiy_epeuXEZaQsHim9DLj9IoJLsB65zIQurm6_Xpyd8zH-fz79Em1xAKEtZ_btYOCxZzceu9LXA7ZWFEnNhANrcotgwbqAaAq0yVMOjI8_u0Os-H16SSQshocfEHcg_JvevJxD1uNte7I0vYQWoFCxC3KBgtjbPCvlUBGFf6ZSE2ywQVB6i14wsp4NQsvbbp9WZ0NPlfRU20Dtm1862ILePpVb8vme9xa1yAmUiVqBZfcgj41Dcyb7fMlw8Znx6d147DvzyP9Ae1Lo-U3xdD2nMQUzhNaZuwcffI1T402hP7QJUXAgBno7inGeQbxK6sowypuxJGiZ9H8g-0UOjRdf3EHkHY4PHnZNwP1hE4Ae5laK_BAN04CTkCgLcuE69dVqWfYxVRdbagbm7fDnNASnKKG3CioJjdyh6hHRwivSPBwNpcL9Kn4IawX3dSUsCADsyT4GmmYq_1jd9K9iW7sEgUVQnevjWRg6owm1v4Zr_p5xqxSPWK0E5j7U1oDFgXzPpYSEGfMOgfnVjbpJ81LkIS_oqAaFL66J1IyNsMDLZEuFQJ3pyFJf7UA",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6203442,
#                     "lng": -122.3297537
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6217418802915,
#                         "lng": -122.3287446197085
#                     },
#                     "southwest": {
#                         "lat": 47.6190439197085,
#                         "lng": -122.3314425802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "REI",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116079265035738039892\">John allen</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0hTjzdiriUcVVPstomveA-VolBrqvWiSH1IktQmwRXh69aDUguJRZKalO8ANwoAN1pgqjW4LUYAoS3KKuWOCNBrT5M-GN6NmImSPFdbHsNgyGnvvQH0XwZ4eryeJmkylEhASmxTWPwcJFsWEzRb7nuV7GhRjKZ15T5j5mFcoEc3n4XCx4uaNRQ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJa_52_zMVkFQRIsX5KSvv41k",
#             "plus_code": {
#                 "compound_code": "JMCC+43 Seattle, WA, USA",
#                 "global_code": "84VVJMCC+43"
#             },
#             "price_level": 3,
#             "rating": 4.7,
#             "reference": "ChIJa_52_zMVkFQRIsX5KSvv41k",
#             "scope": "GOOGLE",
#             "types": [
#                 "shoe_store",
#                 "bicycle_store",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 2040,
#             "vicinity": "222 Yale Avenue North, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.65300999999999,
#                     "lng": -122.317515
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6543746802915,
#                         "lng": -122.3160843197085
#                     },
#                     "southwest": {
#                         "lat": 47.6516767197085,
#                         "lng": -122.3187822802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Recycled Cycles",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111393759693279042582\">Edward Aites</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvLTS7p641OK7ILJcNRg7ZIstk_Y6Gs5ZY3hsjDF-28LYARCk4uKRrOV_GvqC0n8Or_WKzVos9pdut8GnIKBCdOQnYnvmoVnrq4wLrg129Ty1UQrQVUQB3ID84_vpdbgyEhCqGqKiRLOATHUMdNxcUKBJGhTN21oKvbocb0me5A2Q5lbZW4M0zw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJqy0av_EUkFQRJC4a80nWr_k",
#             "plus_code": {
#                 "compound_code": "MM3J+6X Seattle, WA, USA",
#                 "global_code": "84VVMM3J+6X"
#             },
#             "rating": 4.7,
#             "reference": "ChIJqy0av_EUkFQRJC4a80nWr_k",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 285,
#             "vicinity": "1007 Northeast Boat Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6186545,
#                     "lng": -122.3307729
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6199468802915,
#                         "lng": -122.3293627697085
#                     },
#                     "southwest": {
#                         "lat": 47.6172489197085,
#                         "lng": -122.3320607302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Play It Again Sports & Ski",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3006,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103434568382305911708\">Karel Scott</a>"
#                     ],
#                     "photo_reference": "CmRaAAAASd5N57l803N1xoPjoe4Jl8QkGo25Y9P70-eHkOsX7Xov1kLeeSumPgwJ_XQVDgnKKXFONNMpIe4OZYie65Z-OLAtWOvBLnWI6x4QhDYIXEgL8Rk3mzBfYZ_Om0t_MEaxEhAIAxUqQO076vWeAdEXfM7yGhTrgcuKExawq3e1xIlHDfWGF1iiQA",
#                     "width": 5344
#                 }
#             ],
#             "place_id": "ChIJU5tNPjQVkFQRUDMcQiJNK9U",
#             "plus_code": {
#                 "compound_code": "JM99+FM Seattle, WA, USA",
#                 "global_code": "84VVJM99+FM"
#             },
#             "rating": 3.8,
#             "reference": "ChIJU5tNPjQVkFQRUDMcQiJNK9U",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 83,
#             "vicinity": "1304 Stewart Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6494192,
#                     "lng": -122.3420718
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6508195302915,
#                         "lng": -122.3409516697085
#                     },
#                     "southwest": {
#                         "lat": 47.6481215697085,
#                         "lng": -122.3436496302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "evo Seattle Store",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117313142203671738391\">evo Seattle Store</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjzyQI_i7PFURhwvEbAJ2Kd5tC770kOvher7ux6sQdkcndCDF1GXqhfCYyn-402wLIpJK1ZzgEVq5X4n1PNbBtKSzE1_dZS7lzy88Arw4xtMMFs1t-2WBxSwum3ESuYy7EhDLlGgURqo7iF7DtgqEoR-qGhRqQMiQa5yDKUyOKCwv-Tzo3uE4sA",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJF6OR5qgVkFQRZDmlxcZkVQg",
#             "plus_code": {
#                 "compound_code": "JMX5+Q5 Seattle, WA, USA",
#                 "global_code": "84VVJMX5+Q5"
#             },
#             "rating": 4.4,
#             "reference": "ChIJF6OR5qgVkFQRZDmlxcZkVQg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 488,
#             "vicinity": "3500 Stone Way North, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6130575,
#                     "lng": -122.3053132
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6143387802915,
#                         "lng": -122.3039756197085
#                     },
#                     "southwest": {
#                         "lat": 47.61164081970851,
#                         "lng": -122.3066735802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "20/20 Cycle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1700,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114847554661145085738\">Chan</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0Fv81yF9OFE0bPAeoG1cKrcZG2ndtE_m6tpCW-R1GLwn2bon2xEWTLG7qzGilwWQ-vbStL11mkZ6V008Ouhg-lGZfU4glRmPX7yYcwNqWmthYq3s3m-KmAzwcjWMvo-uEhB9m8fUbbt20sWvyEkV_eOHGhSsmnq3at8NoBePOeM84teRb9azDA",
#                     "width": 2550
#                 }
#             ],
#             "place_id": "ChIJaw6Z7dBqkFQR2uo5k5IGigs",
#             "plus_code": {
#                 "compound_code": "JM7V+6V Seattle, WA, USA",
#                 "global_code": "84VVJM7V+6V"
#             },
#             "rating": 4.6,
#             "reference": "ChIJaw6Z7dBqkFQR2uo5k5IGigs",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 104,
#             "vicinity": "2020 East Union Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.63938,
#                     "lng": -122.30234
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6408014802915,
#                         "lng": -122.3009812197085
#                     },
#                     "southwest": {
#                         "lat": 47.6381035197085,
#                         "lng": -122.3036791802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Montlake Bicycle Shop",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111759970092593623056\">Michael Kirk</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjTMkigDEMoaYxNhGYAkBLcESK_55BPF44NU7hkiSMNgVAM6-Nu8jH9vJuhcWsSsLjoJqJ0vPvBNjoqQLYyEUwweq9Gn4ey6nbaehGg9E2noNtHrRUDM5w7LCxt2TsUmLEhB7LdkLVhFJEyUIPXrc7weXGhT8Fl0rInEXsWS2V7Z0DHFHn9cDag",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJwfnihsQUkFQRQvfHB_nTlns",
#             "plus_code": {
#                 "compound_code": "JMQX+Q3 Seattle, WA, USA",
#                 "global_code": "84VVJMQX+Q3"
#             },
#             "rating": 4.6,
#             "reference": "ChIJwfnihsQUkFQRQvfHB_nTlns",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 109,
#             "vicinity": "2223 24th Avenue East, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6523023,
#                     "lng": -122.3558066
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6537609302915,
#                         "lng": -122.3544038697085
#                     },
#                     "southwest": {
#                         "lat": 47.65106296970851,
#                         "lng": -122.3571018302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Wright Brothers Cycle Works",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116075994744502396013\">Creighton Watley</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA2qHApPDZPuoF30dmMjqGjazwXC2SUIjHeO2vCNkGTEZE7v7L5QAa5tdOWItdtztDovOp1nZgH8w620ZGACQ8DCBTVs6zQEvQNvyYjCCpZ8NhcauG8HNyaLso1h8DHwGPEhA0B8B9rh4AGZ63cJDegT44GhT5xkiXUSaAmbDPGakwtSt4bMXwwA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJd46QsakVkFQRqA5Mys-fawo",
#             "plus_code": {
#                 "compound_code": "MJ2V+WM Seattle, WA, USA",
#                 "global_code": "84VVMJ2V+WM"
#             },
#             "rating": 4.9,
#             "reference": "ChIJd46QsakVkFQRqA5Mys-fawo",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 41,
#             "vicinity": "219 North 36th Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.58092069999999,
#                     "lng": -122.3861934
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.5822735802915,
#                         "lng": -122.3850300697085
#                     },
#                     "southwest": {
#                         "lat": 47.5795756197085,
#                         "lng": -122.3877280302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Alki Bike & Board",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112894751944210488979\">Dena Squire</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATl_xOAmbQocl8Axja0tZKlpSPYjCf0YllWOfHuHEeyLGHLS65E8vl324j1YaPtUlIMEkXYE7nyJAe3wd14frJBIXJ_GUJufP3MQR257jSOa-fD8AKfIiC8SCetk1QEU9EhB4AyrnYwuLMNcQmwns7cbGGhQSN1Igi_Xzwzt5o7zKIRiY7_KHwg",
#                     "width": 2222
#                 }
#             ],
#             "place_id": "ChIJg9q352VAkFQRleXDEz3yqj8",
#             "plus_code": {
#                 "compound_code": "HJJ7+9G Seattle, WA, USA",
#                 "global_code": "84VVHJJ7+9G"
#             },
#             "rating": 4.7,
#             "reference": "ChIJg9q352VAkFQRleXDEz3yqj8",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 64,
#             "vicinity": "2606 California Avenue Southwest, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.63931520000001,
#                     "lng": -122.3764281
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6406649302915,
#                         "lng": -122.3749748697085
#                     },
#                     "southwest": {
#                         "lat": 47.6379669697085,
#                         "lng": -122.3776728302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Alpine Hut",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112365431525340212263\">Alpine Hut</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA3W4tDKesjuxi64VP3lAljOqULqIFONoFnvTXzwXcemC2O0e6z6BxF-U62y7MSQl8Z0ChC5O8kjvYYD9KeIctCWFYweoUJjqwb0Eoec8K5n0E7tnbhBwpzrhI3093omU2EhCgPjxnrexIKZ95zCHU-iJUGhTqIvWzZ3GRi0Kl9m2ZlF112GnQmA",
#                     "width": 640
#                 }
#             ],
#             "place_id": "ChIJ2fjT13AVkFQRwWgxT6ed9ZA",
#             "plus_code": {
#                 "compound_code": "JJQF+PC Seattle, WA, USA",
#                 "global_code": "84VVJJQF+PC"
#             },
#             "price_level": 3,
#             "rating": 4.7,
#             "reference": "ChIJ2fjT13AVkFQRwWgxT6ed9ZA",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 82,
#             "vicinity": "2215 15th Avenue West, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.586792,
#                     "lng": -122.3207502
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.5881400802915,
#                         "lng": -122.3194799197085
#                     },
#                     "southwest": {
#                         "lat": 47.5854421197085,
#                         "lng": -122.3221778802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Hill Topper Electric Bike Company",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2769,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111328049530968469401\">Hill Topper Electric Bike Company</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwzjMbmWO-zIRUaRx-uIvqt8Nr4brxZdhsgv3TJ7CWg1Mdaw3tr_7EwO3vi6vP6UjcpaInrvq9FVUf-9TflhWhjsks_LeqOLYPZtd4C36utmc4WB-Im65tXYB1j6_PD6sEhB8Hczz6uOsHG5spB90YR60GhSKDUwNf2u3OVMuaxvmgbB_Uhflmw",
#                     "width": 2610
#                 }
#             ],
#             "place_id": "ChIJNbXwAptqkFQRw-jG7UfaSTs",
#             "plus_code": {
#                 "compound_code": "HMPH+PM Seattle, WA, USA",
#                 "global_code": "84VVHMPH+PM"
#             },
#             "rating": 4.8,
#             "reference": "ChIJNbXwAptqkFQRw-jG7UfaSTs",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 28,
#             "vicinity": "920 South Holgate Street Unit #107, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6703246,
#                     "lng": -122.3133656
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6716528302915,
#                         "lng": -122.3118545697085
#                     },
#                     "southwest": {
#                         "lat": 47.6689548697085,
#                         "lng": -122.3145525302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "R+E Cycles (Rodriguez Bicycle Company)",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 314,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110192047495503287646\">R+E Cycles (Rodriguez Bicycle Company)</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAyx0-FdOS_W6hZYJK4v765yGPWRRvoMUgpPBvGQtXK3IZr_mu2vwJZ6mfaAZYByy9p6mfCg95PC_YpN9XPH3eZQLPPXkXzRpnUiWgN2mzlvPrqIOo8BVhGOBNLCCJL2ViEhB6hUOVzbW1dYM2E2bKLFbqGhTeF_He4xDGqaPxVsZaRcS1aE-RuQ",
#                     "width": 902
#                 }
#             ],
#             "place_id": "ChIJnY2RYWQUkFQRchLayFgcKyo",
#             "plus_code": {
#                 "compound_code": "MMCP+4M Seattle, WA, USA",
#                 "global_code": "84VVMMCP+4M"
#             },
#             "rating": 4.8,
#             "reference": "ChIJnY2RYWQUkFQRchLayFgcKyo",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 45,
#             "vicinity": "5627 University Way Northeast, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6415313,
#                     "lng": -122.3198508
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.64284913029149,
#                         "lng": -122.3186056197085
#                     },
#                     "southwest": {
#                         "lat": 47.6401511697085,
#                         "lng": -122.3213035802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Branford Bike",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102154062818080973009\">jeffrey price</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA2_zRCc9xBfiVayg-qUEC5hEw_d3LC1BB09iEp5f0v25tUadTsOdQcMTnZ9taxR3ni8qRXV2oCWCEcjqXyN3J8kJwgbizN2zvrbythfmTK0GugP0Q6T7M0hjQjF-2En3BEhCyjkw7zwszkfUgqPcDns0RGhSoQIujnm3T9LNfK21Vc_g6ujyC0A",
#                     "width": 1836
#                 }
#             ],
#             "place_id": "ChIJZSWrz-AUkFQRqiIK3OaTArg",
#             "plus_code": {
#                 "compound_code": "JMRJ+J3 Seattle, WA, USA",
#                 "global_code": "84VVJMRJ+J3"
#             },
#             "rating": 3.9,
#             "reference": "ChIJZSWrz-AUkFQRqiIK3OaTArg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "2404 10th Avenue East, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6751866,
#                     "lng": -122.3175252
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6765311802915,
#                         "lng": -122.3160952697085
#                     },
#                     "southwest": {
#                         "lat": 47.6738332197085,
#                         "lng": -122.3187932302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Ride Bicycles Bike Shop",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1530,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106004397642555711445\">Taylor Sizemore</a>"
#                     ],
#                     "photo_reference": "CmRaAAAALxPJ2OBt-OgnN84M1FLaGqorfW0cHbMtsYwhtgvBM67jhz9W83-zLQJs0btxJalU8ARbrXjk2HevjVP_v2Pwq1wLXhaDUTVIss544TYQCzDXZTu4kTFPDceQtY7HCoy0EhCoJCQFmtirR2jqa7J0A0EfGhQx8DHyNkmv8ZK2cgVS8QYNBHFLXg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJM6tHjmUUkFQRNYbdkvxeA8A",
#             "plus_code": {
#                 "compound_code": "MMGJ+3X Seattle, WA, USA",
#                 "global_code": "84VVMMGJ+3X"
#             },
#             "rating": 4.8,
#             "reference": "ChIJM6tHjmUUkFQRNYbdkvxeA8A",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 78,
#             "vicinity": "6405 Roosevelt Way Northeast, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6042863,
#                     "lng": -122.3378203
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60554458029149,
#                         "lng": -122.3363804197085
#                     },
#                     "southwest": {
#                         "lat": 47.60284661970849,
#                         "lng": -122.3390783802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "The Bicycle Repair Shop",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101330920025940637272\">The Bicycle Repair Shop</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA30f3zPI9i0f-1ipR9uqVN2WNxe75XXO0RlU_22zLWz0-c6HbGPGloOkzO04QfVYeBz8ZtEVJXo6H433UqofwufN3IwYlCL1ZzS9JemfK9j1XcRujwPra1b22JkoSD01JEhBtWdHKfqOUqW2dYpE_wnB7GhQeMS9tURDzGi7xaIG56IJuzQxFpw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJY8F11a9qkFQRHNkYuwNpSKk",
#             "plus_code": {
#                 "compound_code": "JM36+PV Seattle, WA, USA",
#                 "global_code": "84VVJM36+PV"
#             },
#             "rating": 4.9,
#             "reference": "ChIJY8F11a9qkFQRHNkYuwNpSKk",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 155,
#             "vicinity": "68 Madison Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6127018,
#                     "lng": -122.3186497
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6140510302915,
#                         "lng": -122.3173802197085
#                     },
#                     "southwest": {
#                         "lat": 47.6113530697085,
#                         "lng": -122.3200781802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "M\u00e9tier Seattle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103859999501985453644\">M\u00e9tier Seattle</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAGtgjqwzNJ5hQyfzERySxLUc670onzAsPboMxwTwsvAhQZD1o7Ln5f7h_PAU442rEutfVsvrA1-M4DTcjBuFv3h_HlQB_49vUZjrtc-K7QQsnXmE0A-jvyvie9p7DfgVzEhCkze8cC8FxGVfszxtglSe2GhTfKFQqCbqa2vZY0e2jOVU6oINeHQ",
#                     "width": 2500
#                 }
#             ],
#             "place_id": "ChIJsRdC0AcVkFQR-M_ZN_wWOgU",
#             "plus_code": {
#                 "compound_code": "JM7J+3G Seattle, WA, USA",
#                 "global_code": "84VVJM7J+3G"
#             },
#             "rating": 4.3,
#             "reference": "ChIJsRdC0AcVkFQR-M_ZN_wWOgU",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "health",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 74,
#             "vicinity": "1017 East Union Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.615078,
#                     "lng": -122.3278078
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6165025802915,
#                         "lng": -122.3264576197085
#                     },
#                     "southwest": {
#                         "lat": 47.6138046197085,
#                         "lng": -122.3291555802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Rapha Seattle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1333,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100268104947182026510\">Josh Ross</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwP4hNO2zyzcWeADhIS3Tgwe6f9ASAinkO9E4z1EJcFX-62TGAepO8jebA4snGSX3-V3TYPSRddBm0PltVfVE-Zy9OVbFWfRT8vGr_rJNYVRoFYdLHGLi09Khpu4yrttxEhCrxADKprgFJjHvj8v73lD2GhR6fyz1obqwrzDe3Q299a1ynBTuIw",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJD8j-K8tqkFQRxaf5FFiDUeg",
#             "plus_code": {
#                 "compound_code": "JM8C+2V Seattle, WA, USA",
#                 "global_code": "84VVJM8C+2V"
#             },
#             "rating": 4.7,
#             "reference": "ChIJD8j-K8tqkFQRxaf5FFiDUeg",
#             "scope": "GOOGLE",
#             "types": [
#                 "clothing_store",
#                 "cafe",
#                 "bicycle_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 100,
#             "vicinity": "301 East Pine Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6159809,
#                     "lng": -122.3353362
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6173763302915,
#                         "lng": -122.3339266197085
#                     },
#                     "southwest": {
#                         "lat": 47.6146783697085,
#                         "lng": -122.3366245802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "MBR Bike Shop + Mobile Bicycle Rescue",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3672,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103645242770530988062\">Blair Daly</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARAP6aNZXhBJaKvuYW6aTUtRzsQx_n1koTH71BVvcgUZxwm4Mc942WbysCuPpxWZygZmGGZH8_cUyTsULIqM0GHIDkimSG0F9snyM4UmjRQ1kMK0vxn9HsRqEYyXvbs6xEhAJqgdQS-G6mKjQAY14-vsIGhQnz0fLuubLZhn5MXER7Tqfu2aBHA",
#                     "width": 7676
#                 }
#             ],
#             "place_id": "ChIJxx8siEoVkFQRf-LYmhygEug",
#             "plus_code": {
#                 "compound_code": "JM87+9V Seattle, WA, USA",
#                 "global_code": "84VVJM87+9V"
#             },
#             "rating": 4.2,
#             "reference": "ChIJxx8siEoVkFQRf-LYmhygEug",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 33,
#             "vicinity": "1961 9th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6157017,
#                     "lng": -122.3408794
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6170797302915,
#                         "lng": -122.3394278697085
#                     },
#                     "southwest": {
#                         "lat": 47.61438176970851,
#                         "lng": -122.3421258302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Velo Bike Shop",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105746056324544705882\">Velo Bike Shop</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA74eiO8unIq3eQjcTlFp-t-qMGvBqka3nFLVfHvEDKpZBmm-Gjqfk_6OtD7NUFZVuv_Jc9lWJERh-avXZsmzkVVg4XCejeMe3wZUGHOHedE40zl_T0RC-UGclzInS-9SWEhBRkfBq_Aau6tM0WzOnODvHGhR-h5R9oFH8AQPFWbSaz3zm-sfsWQ",
#                     "width": 1504
#                 }
#             ],
#             "place_id": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "plus_code": {
#                 "compound_code": "JM85+7J Seattle, WA, USA",
#                 "global_code": "84VVJM85+7J"
#             },
#             "rating": 4,
#             "reference": "ChIJKTKBss1qkFQR7soJvq6mDCg",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "parking",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 114,
#             "vicinity": "2151 6th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.61374139999999,
#                     "lng": -122.3175795
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6148981802915,
#                         "lng": -122.3162434197085
#                     },
#                     "southwest": {
#                         "lat": 47.6122002197085,
#                         "lng": -122.3189413802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Good Weather Bicycle & Cafe",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104241906108733953361\">Good Weather Bicycle &amp; Cafe</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA36zyOsalrJAYoodFuemMcO-43zQdHF0NQddkESFXHHj4fHMzgu4ErmXZZRQyE2gaXtk2KmRGC-SlChH66YIsWJyiPx4TtxCaQX_xSQkPInCVz1BMpeMDWiyjKCnYjlE7EhAbEZ0Baqo8A8nL4Czen-yhGhTOGEIr3Y1jRWkCn0yEw-mnTrF65w",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "plus_code": {
#                 "compound_code": "JM7J+FX Seattle, WA, USA",
#                 "global_code": "84VVJM7J+FX"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ7b3xss1qkFQRESZrR5_st9Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "cafe",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 116,
#             "vicinity": "1424 11th Avenue West, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.5723178,
#                     "lng": -122.3704508
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.5736415802915,
#                         "lng": -122.3692355697085
#                     },
#                     "southwest": {
#                         "lat": 47.5709436197085,
#                         "lng": -122.3719335302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Westside Bicycle",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1054,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105473396159134474821\">Westside Bicycle</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAuuJVPmydFdj8wp582YwvXW4sAwY6tqmhydSXv8gl6icoBiALaPW5YXiXLjj8Le-Wi0SEd8CiKa8rYNNWw13cM6jKP35MzPi0ygf2N_g3A19S7_1g324WstS5_HcuPEOPEhDNDdyTj9cC7E8V4pbg-FNpGhTr3XIeHj5sszQzMAxyFbDU6DpVnQ",
#                     "width": 1482
#                 }
#             ],
#             "place_id": "ChIJl3Tf5URAkFQRePZ3KeMsSWY",
#             "plus_code": {
#                 "compound_code": "HJCH+WR Seattle, WA, USA",
#                 "global_code": "84VVHJCH+WR"
#             },
#             "rating": 4.8,
#             "reference": "ChIJl3Tf5URAkFQRePZ3KeMsSWY",
#             "scope": "GOOGLE",
#             "types": [
#                 "bicycle_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 75,
#             "vicinity": "3418 Harbor Avenue Southwest, Seattle"
#         }
#     ],
#     "status": "OK"
# }

# %%
# 4. Find a balloon store near the White House.
target_search = "Balloon Store"
dc_coords = "38.8976763,-77.0365298"

# redefine params
params = {
    "location": dc_coords,
    "keyword": target_search,
    "radius": radius,
    "key": gkey
}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

print("Drill #4: A Balloon Store Near the White House")

# Run request
dc_balloons = requests.get(base_url, params).json()

# Print the JSON (pretty printed)
# print(json.dumps(dc_balloons, indent=4, sort_keys=True))

# Print the name and address of the first balloon shop that appears
print(dc_balloons["results"][0]["name"])
print(dc_balloons["results"][0]["vicinity"])
# Out:
# Drill #4: A Balloon Store Near the White House
# Party City
# 5522 Leesburg Pike, Falls Church

# %%
# 5. Find the nearest dentist to your house.
# Hint: Use Google Maps to find your latitude and Google Places to find
# the dentist. You may also need the rankby property.

# Google geocode to find lat, lng
my_address = "151 Sip Ave"


params = {
    "address": my_address,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #5: A Dentist Near My House")

my_geo = requests.get(base_url, params).json()

lat = my_geo["results"][0]["geometry"]["location"]["lat"]
lng = my_geo["results"][0]["geometry"]["location"]["lng"]


# Use lat, lng to use places API to find nearest dentist
target_search = "dentist"

params = {
    "location": f"{lat},{lng}",
    "types": target_search,
    "rankby": "distance",
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
my_dentist = response.json()

# Print the JSON (pretty printed)
# print(json.dumps(my_dentist, indent=4, sort_keys=True))

# Print the name and address of the first dentist that appears
print(my_dentist["results"][0]["name"])
print(my_dentist["results"][0]["vicinity"])
# Out:
# Drill #5
# Giorgio T Di Vincenzo PC: Lefkowitz David J DDS
# 312 Academy Street # A, Jersey City

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
my_phrase = "best restaurant in Washington, DC"
target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

params = {
    "query": my_phrase,
    "key": gkey
}

print("Drill #6: Bonus")

response = requests.get(target_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
happy_places = response.json()
# print(json.dumps(happy_places, indent=4, sort_keys=True))

counter = 0

for place in happy_places["results"]:
    print(place["name"])
    print(place["formatted_address"])
    counter += 1
    if counter == 5:
        break
# Out:
# Drill #6: Bonus
# The Dabney
# 122 Blagden Alley NW, Washington, DC 20001, United States
# Old Ebbitt Grill
# 675 15th St NW, Washington, DC 20005, United States
# Bistro Aracosia
# 5100 MacArthur Blvd, Washington, DC 20016, United States
# Le Diplomate
# 1601 14th St NW, Washington, DC 20009, United States
# Maydan
# 1346 Florida Ave NW, Washington, DC 20009, United States
