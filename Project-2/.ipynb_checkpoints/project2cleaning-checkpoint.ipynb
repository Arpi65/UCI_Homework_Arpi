# %%
import panda as pd

# %%
ny_file="rowdata/books_uniq_weeks.csv"
good_file="rowdata/goodreads_books.csv"
google_file="rowdata/google_books_1299.csv"

ny_df=pd.read_csv(ny_file, encoding = "ISO-8859-1")
good_df=pd.read_csv(good_file, encoding = "ISO-8859-1")
google_df=pd.read_csv(google_file, encoding = "ISO-8859-1")

# %%
ny_pd.head()
# Out:
#        publisher  dagger                                   book_review_link  \
# 0      Riverhead       0  https://www.nytimes.com/2015/01/05/books/the-g...
# 1       Scribner       0                                                NaN
# 2        Vintage       0                                                NaN
# 3   St. Martin's       0                                                NaN
# 4  Penguin Group       0  https://www.nytimes.com/2009/02/19/books/19mas...
#
#              author primary_isbn10  price primary_isbn13  \
# 0     Paula Hawkins     1594634025      0    9.78159E+12
# 1     Anthony Doerr     1501173219      0     9.7815E+12
# 2         E L James      525431888      0    9.78053E+12
# 3    Kristin Hannah     1466850604      0    9.78147E+12
# 4  Kathryn Stockett     1440697663      0    9.78144E+12
#
#                                   sunday_review_link      date  \
# 0  https://www.nytimes.com/2015/02/01/books/revie...   2/19/17
# ...

# %%
good_df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling/Mary GrandPr̩           4.57   439785960  9.78044E+12
# 1  J.K. Rowling/Mary GrandPr̩           4.49   439358078  9.78044E+12
# 2                 J.K. Rowling           4.42   439554896  9.78044E+12
# 3  J.K. Rowling/Mary GrandPr̩           4.56  043965548X  9.78044E+12
# 4  J.K. Rowling/Mary GrandPr̩           4.78   439682584  9.78044E+12
#
#   language_code   num_pages  ratings_count  text_reviews_count  \
# 0           eng         652        2095690               27591
# ...

# %%
good_title=["isbn13","title","authors","publication_date","publisher"]
good_transformed=good_df[good_title]
good_transformed.head()
# Out:
#         isbn13                                              title  \
# 0  9.78044E+12  Harry Potter and the Half-Blood Prince (Harry ...
# 1  9.78044E+12  Harry Potter and the Order of the Phoenix (Har...
# 2  9.78044E+12  Harry Potter and the Chamber of Secrets (Harry...
# 3  9.78044E+12  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  9.78044E+12  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors publication_date        publisher
# 0  J.K. Rowling/Mary GrandPr̩        9/16/2006  Scholastic Inc.
# 1  J.K. Rowling/Mary GrandPr̩         9/1/2004  Scholastic Inc.
# 2                 J.K. Rowling        11/1/2003       Scholastic
# 3  J.K. Rowling/Mary GrandPr̩         5/1/2004  Scholastic Inc.
# 4  J.K. Rowling/Mary GrandPr̩        9/13/2004       Scholastic

# %%
google_pd.head()
# Out:
#    Unnamed: 0                                             title  \
# 0           0                        Attack on Titan: Volume 13
# 1           1  Antiques Roadkill: A Trash 'n' Treasures Mystery
# 2           2                    The Art of Super Mario Odyssey
# 3           3    Getting Away Is Deadly: An Ellie Avery Mystery
# 4           4         The Painted Man (The Demon Cycle, Book 1)
#
#            author  rating voters   price currency  \
# 0  Hajime Isayama     4.6    428   43.28      SAR
# 1   Barbara Allan     3.3     23   26.15      SAR
# 2        Nintendo     3.9      9  133.85      SAR
# 3     Sara Rosett     4.0     10   26.15      SAR
# 4  Peter V. Brett     4.5    577   28.54      SAR
#
#                                          description  \
# 0  NO SAFE PLACE LEFT At great cost to the Garris...
# 1  Determined to make a new start in her quaint h...
# 2  Take a globetrotting journey all over the worl...
# 3  With swollen feet and swelling belly, pregnant...
# ...

# %%
#need to create the DB first
#dataframe.set_index("colname", inplace=True)
connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{connection_string}')
# Confirm tables
engine.table_names()

# %%
#load frames into data base

# dataframe.to_sql(name='<tablename>', con=engine, if_exists='append', index=True)
